# %%
import math
from sympy import*
from sympy.plotting import plot

# %%
x= symbols('x')
fx= -12*x**4- 18*x**3+ 5*x**2- 30
fx
#print(solve(fx))
# Out:
# -12*x**4 - 18*x**3 + 5*x**2 - 30

# %%
solve(fx)
# Out:
# [-3/8 - sqrt(121/144 + 4345/(2592*(195895/373248 + 5*sqrt(5389446)*I/20736)**(1/3)) + 2*(195895/373248 + 5*sqrt(5389446)*I/20736)**(1/3))/2 - sqrt(121/72 - 2*(195895/373248 + 5*sqrt(5389446)*I/20736)**(1/3) + 47/(32*sqrt(121/144 + 4345/(2592*(195895/373248 + 5*sqrt(5389446)*I/20736)**(1/3)) + 2*(195895/373248 + 5*sqrt(5389446)*I/20736)**(1/3))) - 4345/(2592*(195895/373248 + 5*sqrt(5389446)*I/20736)**(1/3)))/2,
#  -3/8 + sqrt(121/144 + 4345/(2592*(195895/373248 + 5*sqrt(5389446)*I/20736)**(1/3)) + 2*(195895/373248 + 5*sqrt(5389446)*I/20736)**(1/3))/2 - sqrt(121/72 - 2*(195895/373248 + 5*sqrt(5389446)*I/20736)**(1/3) - 47/(32*sqrt(121/144 + 4345/(2592*(195895/373248 + 5*sqrt(5389446)*I/20736)**(1/3)) + 2*(195895/373248 + 5*sqrt(5389446)*I/20736)**(1/3))) - 4345/(2592*(195895/373248 + 5*sqrt(5389446)*I/20736)**(1/3)))/2,
# ...

# %%
p= plot(fx,(x, -10, 10))

# %%
solve(fx)#корни
# Out:
# [0, -9/16 + sqrt(1209)/48, -sqrt(1209)/48 - 9/16]

# %%
solve(fx)
print(solve(fx))
# Out:
# [0, -9/16 + sqrt(1209)/48, -sqrt(1209)/48 - 9/16]

# %%
f=diff(fx)

print(solve(f>0)) #интервалы на которых функция возрастает
print(solve(f<0))#интервалы на которых функция убывает
print(solve(f))# вершина
# Out:
# (-5/6 < x) & (x < 1/12)
# ((-oo < x) & (x < -5/6)) | ((1/12 < x) & (x < oo))
# [-5/6, 1/12]

# %%
print(solve(fx>0))# промежуток на котором функция больше 0
print(solve(fx<0))# промежуток на котором функция меньше 0
# Out:
# ((-oo < x) & (x < -sqrt(1209)/48 - 9/16)) | ((0 < x) & (x < -9/16 + sqrt(1209)/48))
# ((x < 0) & (-sqrt(1209)/48 - 9/16 < x)) | ((x < oo) & (-9/16 + sqrt(1209)/48 < x))
